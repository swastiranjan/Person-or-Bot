# %% [markdown]
# Importing the required Python libraries for data handling, model training, and evaluation.

# %%
import pandas as pd
data=pd.read_csv("person_or_bot.csv")
data.head()
# Out:
#    avg_key_de  std_key_de  backspace  paste_use  typing_spe  label
# 0         190          45         12          1         3.0      0
# 1          85           8          0          1        10.3      1
# 2         175          40         11          0         3.0      0
# 3         110          25          2          1         7.0      1
# 4         220          70         20          0         2.6      0

# %% [markdown]
# Loading the typing behavior dataset and performing an initial inspection to verify structure and values.

# %%
X = data.drop("label", axis=1)
y = data["label"]

print(X.head)
print(y.head)
# Out:
# <bound method NDFrame.head of     avg_key_de  std_key_de  backspace  paste_use  typing_spe
# 0          190          45         12          1         3.0
# 1           85           8          0          1        10.3
# 2          175          40         11          0         3.0
# 3          110          25          2          1         7.0
# 4          220          70         20          0         2.6
# ..         ...         ...        ...        ...         ...
# 57         125          19          2          1         6.7
# 58         215          63         17          0         2.8
# 59          95          10          1          1         9.5
# 60         140          42         20          0         5.2
# 61         105          13          1          0         8.4
#
# [62 rows x 5 columns]>
# <bound method NDFrame.head of 0     0
# 1     1
# 2     0
# 3     1
# 4     0
#      ..
# 57    1
# 58    0
# 59    1
# 60    0
# 61    1
# Name: label, Length: 62, dtype: int64>

# %% [markdown]
# Splitting the dataset into training and testing sets to evaluate the model on unseen data.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.35, random_state=7
)

model = RandomForestClassifier(n_estimators=100, random_state=7)
model.fit(X_train, y_train)

y_pred = model.predict(X_test2)
print("Accuracy (35% test):", accuracy_score(y_test, y_pred))
# Out:
# Accuracy (35% test): 0.9545454545454546

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluating the overall performance of the model using accuracy as a baseline metric.

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[8 0]
#  [0 8]]

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    model,
    X,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross-validation accuracies:", scores)
print("Mean CV accuracy:", scores.mean())
# Out:
# Cross-validation accuracies: [1.         0.92307692 1.         1.         1.        ]
# Mean CV accuracy: 0.9846153846153847
